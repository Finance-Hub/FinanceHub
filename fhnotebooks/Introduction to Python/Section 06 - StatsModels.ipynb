# %% [markdown]
# # StatsModels
# statsmodels is a Python module that provides classes and functions for the estimation of many different statistical models, as well as for conducting statistical tests, and statistical data exploration. An extensive list of result statistics are available for each estimator. The results are tested against existing statistical packages to ensure that they are correct.
#
# In other words, this package has all the **classic models from a traditional econometrics course**. Here, we are going to give some examples.

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns  # we are going to grab example data from seaborn's dataset

# %%
def get_SGS_data(series_id, series_name):
    url = f'https://api.bcb.gov.br/dados/serie/bcdata.sgs.{str(series_id)}/dados?formato=json'
    df = pd.read_json(url)
    df = df.set_index(pd.to_datetime(df['data'], dayfirst=True)).drop('data', axis='columns')
    df.columns = [series_name]
    return df

# %% [markdown]
# # Linear Regression
# In this example we are going to use the "tips" dataset.

# %%
tips = sns.load_dataset("tips")
tips.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 38        18.69  2.31    Male     No   Sat  Dinner     3
# 211       25.89  5.16    Male    Yes   Sat  Dinner     4
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 135        8.51  1.25  Female     No  Thur   Lunch     2
# 64        17.59  2.64    Male     No   Sat  Dinner     3
# 36        16.31  2.00    Male     No   Sat  Dinner     3
# 145        8.35  1.50  Female     No  Thur   Lunch     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2

# %% [markdown]
# Let's make a simple regression
#
# $$
# tip = \beta_{0} + \beta_{1} total\_bill + \beta_{2} size + \varepsilon
# $$
#
# One way we can handle this regression is the traditional way: defining the $X$ and $y$ matrices

# %%
y = tips['tip'].values
X = tips[['total_bill', 'size']].values
X = sm.add_constant(X)
X
# Out:
# array([[ 1.  , 16.99,  2.  ],
#        [ 1.  , 10.34,  3.  ],
#        [ 1.  , 21.01,  3.  ],
#        [ 1.  , 23.68,  2.  ],
#        [ 1.  , 24.59,  4.  ],
#        [ 1.  , 25.29,  4.  ],
#        [ 1.  ,  8.77,  2.  ],
#        [ 1.  , 26.88,  4.  ],
#        [ 1.  , 15.04,  2.  ],
#        [ 1.  , 14.78,  2.  ],
#        [ 1.  , 10.27,  2.  ],
#        [ 1.  , 35.26,  4.  ],
#        [ 1.  , 15.42,  2.  ],
#        [ 1.  , 18.43,  4.  ],
#        [ 1.  , 14.83,  2.  ],
#        [ 1.  , 21.58,  2.  ],
#        [ 1.  , 10.33,  3.  ],
#        [ 1.  , 16.29,  3.  ],
#        [ 1.  , 16.97,  3.  ],
#        [ 1.  , 20.65,  3.  ],
#        [ 1.  , 17.92,  2.  ],
#        [ 1.  , 20.29,  2.  ],
#        [ 1.  , 15.77,  2.  ],
#        [ 1.  , 39.42,  4.  ],
#        [ 1.  , 19.82,  2.  ],
#        [ 1.  , 17.81,  4.  ],
#        [ 1.  , 13.37,  2.  ],
#        [ 1.  , 12.69,  2.  ],
#        [ 1.  , 21.7 ,  2.  ],
#        [ 1.  , 19.65,  2.  ],
#        [ 1.  ,  9.55,  2.  ],
#        [ 1.  , 18.35,  4.  ],
#        [ 1.  , 15.06,  2.  ],
#        [ 1.  , 20.69,  4.  ],
#        [ 1.  , 17.78,  2.  ],
#        [ 1.  , 24.06,  3.  ],
#        [ 1.  , 16.31,  3.  ],
#        [ 1.  , 16.93,  3.  ],
#        [ 1.  , 18.69,  3.  ],
#        [ 1.  , 31.27,  3.  ],
#        [ 1.  , 16.04,  3.  ],
#        [ 1.  , 17.46,  2.  ],
#        [ 1.  , 13.94,  2.  ],
#        [ 1.  ,  9.68,  2.  ],
#        [ 1.  , 30.4 ,  4.  ],
#        [ 1.  , 18.29,  2.  ],
#        [ 1.  , 22.23,  2.  ],
#        [ 1.  , 32.4 ,  4.  ],
#        [ 1.  , 28.55,  3.  ],
#        [ 1.  , 18.04,  2.  ],
#        [ 1.  , 12.54,  2.  ],
#        [ 1.  , 10.29,  2.  ],
#        [ 1.  , 34.81,  4.  ],
#        [ 1.  ,  9.94,  2.  ],
#        [ 1.  , 25.56,  4.  ],
#        [ 1.  , 19.49,  2.  ],
#        [ 1.  , 38.01,  4.  ],
#        [ 1.  , 26.41,  2.  ],
#        [ 1.  , 11.24,  2.  ],
#        [ 1.  , 48.27,  4.  ],
#        [ 1.  , 20.29,  2.  ],
#        [ 1.  , 13.81,  2.  ],
#        [ 1.  , 11.02,  2.  ],
#        [ 1.  , 18.29,  4.  ],
#        [ 1.  , 17.59,  3.  ],
#        [ 1.  , 20.08,  3.  ],
#        [ 1.  , 16.45,  2.  ],
#        [ 1.  ,  3.07,  1.  ],
#        [ 1.  , 20.23,  2.  ],
#        [ 1.  , 15.01,  2.  ],
#        [ 1.  , 12.02,  2.  ],
#        [ 1.  , 17.07,  3.  ],
#        [ 1.  , 26.86,  2.  ],
#        [ 1.  , 25.28,  2.  ],
#        [ 1.  , 14.73,  2.  ],
#        [ 1.  , 10.51,  2.  ],
#        [ 1.  , 17.92,  2.  ],
#        [ 1.  , 27.2 ,  4.  ],
#        [ 1.  , 22.76,  2.  ],
#        [ 1.  , 17.29,  2.  ],
#        [ 1.  , 19.44,  2.  ],
#        [ 1.  , 16.66,  2.  ],
#        [ 1.  , 10.07,  1.  ],
#        [ 1.  , 32.68,  2.  ],
#        [ 1.  , 15.98,  2.  ],
#        [ 1.  , 34.83,  4.  ],
#        [ 1.  , 13.03,  2.  ],
#        [ 1.  , 18.28,  2.  ],
#        [ 1.  , 24.71,  2.  ],
#        [ 1.  , 21.16,  2.  ],
#        [ 1.  , 28.97,  2.  ],
#        [ 1.  , 22.49,  2.  ],
#        [ 1.  ,  5.75,  2.  ],
#        [ 1.  , 16.32,  2.  ],
#        [ 1.  , 22.75,  2.  ],
#        [ 1.  , 40.17,  4.  ],
#        [ 1.  , 27.28,  2.  ],
#        [ 1.  , 12.03,  2.  ],
#        [ 1.  , 21.01,  2.  ],
#        [ 1.  , 12.46,  2.  ],
#        [ 1.  , 11.35,  2.  ],
#        [ 1.  , 15.38,  2.  ],
#        [ 1.  , 44.3 ,  3.  ],
#        [ 1.  , 22.42,  2.  ],
#        [ 1.  , 20.92,  2.  ],
#        [ 1.  , 15.36,  2.  ],
#        [ 1.  , 20.49,  2.  ],
#        [ 1.  , 25.21,  2.  ],
#        [ 1.  , 18.24,  2.  ],
#        [ 1.  , 14.31,  2.  ],
#        [ 1.  , 14.  ,  2.  ],
#        [ 1.  ,  7.25,  1.  ],
#        [ 1.  , 38.07,  3.  ],
#        [ 1.  , 23.95,  2.  ],
#        [ 1.  , 25.71,  3.  ],
#        [ 1.  , 17.31,  2.  ],
#        [ 1.  , 29.93,  4.  ],
#        [ 1.  , 10.65,  2.  ],
#        [ 1.  , 12.43,  2.  ],
#        [ 1.  , 24.08,  4.  ],
#        [ 1.  , 11.69,  2.  ],
#        [ 1.  , 13.42,  2.  ],
#        [ 1.  , 14.26,  2.  ],
#        [ 1.  , 15.95,  2.  ],
#        [ 1.  , 12.48,  2.  ],
#        [ 1.  , 29.8 ,  6.  ],
#        [ 1.  ,  8.52,  2.  ],
#        [ 1.  , 14.52,  2.  ],
#        [ 1.  , 11.38,  2.  ],
#        [ 1.  , 22.82,  3.  ],
#        [ 1.  , 19.08,  2.  ],
#        [ 1.  , 20.27,  2.  ],
#        [ 1.  , 11.17,  2.  ],
#        [ 1.  , 12.26,  2.  ],
#        [ 1.  , 18.26,  2.  ],
#        [ 1.  ,  8.51,  2.  ],
#        [ 1.  , 10.33,  2.  ],
#        [ 1.  , 14.15,  2.  ],
#        [ 1.  , 16.  ,  2.  ],
#        [ 1.  , 13.16,  2.  ],
#        [ 1.  , 17.47,  2.  ],
#        [ 1.  , 34.3 ,  6.  ],
#        [ 1.  , 41.19,  5.  ],
#        [ 1.  , 27.05,  6.  ],
#        [ 1.  , 16.43,  2.  ],
#        [ 1.  ,  8.35,  2.  ],
#        [ 1.  , 18.64,  3.  ],
#        [ 1.  , 11.87,  2.  ],
#        [ 1.  ,  9.78,  2.  ],
#        [ 1.  ,  7.51,  2.  ],
#        [ 1.  , 14.07,  2.  ],
#        [ 1.  , 13.13,  2.  ],
#        [ 1.  , 17.26,  3.  ],
#        [ 1.  , 24.55,  4.  ],
#        [ 1.  , 19.77,  4.  ],
#        [ 1.  , 29.85,  5.  ],
#        [ 1.  , 48.17,  6.  ],
#        [ 1.  , 25.  ,  4.  ],
#        [ 1.  , 13.39,  2.  ],
#        [ 1.  , 16.49,  4.  ],
#        [ 1.  , 21.5 ,  4.  ],
#        [ 1.  , 12.66,  2.  ],
#        [ 1.  , 16.21,  3.  ],
#        [ 1.  , 13.81,  2.  ],
#        [ 1.  , 17.51,  2.  ],
#        [ 1.  , 24.52,  3.  ],
#        [ 1.  , 20.76,  2.  ],
#        [ 1.  , 31.71,  4.  ],
#        [ 1.  , 10.59,  2.  ],
#        [ 1.  , 10.63,  2.  ],
#        [ 1.  , 50.81,  3.  ],
#        [ 1.  , 15.81,  2.  ],
#        [ 1.  ,  7.25,  2.  ],
#        [ 1.  , 31.85,  2.  ],
#        [ 1.  , 16.82,  2.  ],
#        [ 1.  , 32.9 ,  2.  ],
#        [ 1.  , 17.89,  2.  ],
#        [ 1.  , 14.48,  2.  ],
#        [ 1.  ,  9.6 ,  2.  ],
#        [ 1.  , 34.63,  2.  ],
#        [ 1.  , 34.65,  4.  ],
#        [ 1.  , 23.33,  2.  ],
#        [ 1.  , 45.35,  3.  ],
#        [ 1.  , 23.17,  4.  ],
#        [ 1.  , 40.55,  2.  ],
#        [ 1.  , 20.69,  5.  ],
#        [ 1.  , 20.9 ,  3.  ],
#        [ 1.  , 30.46,  5.  ],
#        [ 1.  , 18.15,  3.  ],
#        [ 1.  , 23.1 ,  3.  ],
#        [ 1.  , 15.69,  2.  ],
#        [ 1.  , 19.81,  2.  ],
#        [ 1.  , 28.44,  2.  ],
#        [ 1.  , 15.48,  2.  ],
#        [ 1.  , 16.58,  2.  ],
#        [ 1.  ,  7.56,  2.  ],
#        [ 1.  , 10.34,  2.  ],
#        [ 1.  , 43.11,  4.  ],
#        [ 1.  , 13.  ,  2.  ],
#        [ 1.  , 13.51,  2.  ],
#        [ 1.  , 18.71,  3.  ],
#        [ 1.  , 12.74,  2.  ],
#        [ 1.  , 13.  ,  2.  ],
#        [ 1.  , 16.4 ,  2.  ],
#        [ 1.  , 20.53,  4.  ],
#        [ 1.  , 16.47,  3.  ],
#        [ 1.  , 26.59,  3.  ],
#        [ 1.  , 38.73,  4.  ],
#        [ 1.  , 24.27,  2.  ],
#        [ 1.  , 12.76,  2.  ],
#        [ 1.  , 30.06,  3.  ],
#        [ 1.  , 25.89,  4.  ],
#        [ 1.  , 48.33,  4.  ],
#        [ 1.  , 13.27,  2.  ],
#        [ 1.  , 28.17,  3.  ],
#        [ 1.  , 12.9 ,  2.  ],
#        [ 1.  , 28.15,  5.  ],
#        [ 1.  , 11.59,  2.  ],
#        [ 1.  ,  7.74,  2.  ],
#        [ 1.  , 30.14,  4.  ],
#        [ 1.  , 12.16,  2.  ],
#        [ 1.  , 13.42,  2.  ],
#        [ 1.  ,  8.58,  1.  ],
#        [ 1.  , 15.98,  3.  ],
#        [ 1.  , 13.42,  2.  ],
#        [ 1.  , 16.27,  2.  ],
#        [ 1.  , 10.09,  2.  ],
#        [ 1.  , 20.45,  4.  ],
#        [ 1.  , 13.28,  2.  ],
#        [ 1.  , 22.12,  2.  ],
#        [ 1.  , 24.01,  4.  ],
#        [ 1.  , 15.69,  3.  ],
#        [ 1.  , 11.61,  2.  ],
#        [ 1.  , 10.77,  2.  ],
#        [ 1.  , 15.53,  2.  ],
#        [ 1.  , 10.07,  2.  ],
#        [ 1.  , 12.6 ,  2.  ],
#        [ 1.  , 32.83,  2.  ],
#        [ 1.  , 35.83,  3.  ],
#        [ 1.  , 29.03,  3.  ],
#        [ 1.  , 27.18,  2.  ],
#        [ 1.  , 22.67,  2.  ],
#        [ 1.  , 17.82,  2.  ],
#        [ 1.  , 18.78,  2.  ]])

# %%
results = sm.OLS(y, X).fit()
results.summary()  # try using print
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     105.9
# Date:                Sun, 26 Aug 2018   Prob (F-statistic):           9.67e-34
# Time:                        21:01:49   Log-Likelihood:                -347.99
# No. Observations:                 244   AIC:                             702.0
# Df Residuals:                     241   BIC:                             712.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6689      0.194      3.455      0.001       0.288       1.050
# x1             0.0927      0.009     10.172      0.000       0.075       0.111
# x2             0.1926      0.085      2.258      0.025       0.025       0.361
# ==============================================================================
# Omnibus:                       24.753   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.169
# Skew:                           0.545   Prob(JB):                     9.43e-11
# Kurtosis:                       4.831   Cond. No.                         67.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# Although defining the matrices works very well for putting models in production, it is not that intuitive to visualize your work
# and it is not a friendly way to explore different specfications, specially if you start adding transformed variables or working with dummy variables.
#
# That is where Statsmodels got some inspiration from R and built a functionality that allows you to specify models in the same way R does.

# %%
results = smf.ols('tip ~ total_bill + size', data=tips).fit()  # try including a categorical variable, like 'sex' or 'day'
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    tip   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.463
# Method:                 Least Squares   F-statistic:                     105.9
# Date:                Sun, 26 Aug 2018   Prob (F-statistic):           9.67e-34
# Time:                        21:02:53   Log-Likelihood:                -347.99
# No. Observations:                 244   AIC:                             702.0
# Df Residuals:                     241   BIC:                             712.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6689      0.194      3.455      0.001       0.288       1.050
# total_bill     0.0927      0.009     10.172      0.000       0.075       0.111
# size           0.1926      0.085      2.258      0.025       0.025       0.361
# ==============================================================================
# Omnibus:                       24.753   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               46.169
# Skew:                           0.545   Prob(JB):                     9.43e-11
# Kurtosis:                       4.831   Cond. No.                         67.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# The `results` varible stores everything you need from the output above and more

# %%
dir(results)
# Out:
# ['HC0_se',
#  'HC1_se',
#  'HC2_se',
#  'HC3_se',
#  '_HCCM',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_cache',
#  '_data_attr',
#  '_get_robustcov_results',
#  '_is_nested',
#  '_wexog_singular_values',
#  'aic',
#  'bic',
#  'bse',
#  'centered_tss',
#  'compare_f_test',
#  'compare_lm_test',
#  'compare_lr_test',
#  'condition_number',
#  'conf_int',
#  'conf_int_el',
#  'cov_HC0',
#  'cov_HC1',
#  'cov_HC2',
#  'cov_HC3',
#  'cov_kwds',
#  'cov_params',
#  'cov_type',
#  'df_model',
#  'df_resid',
#  'diagn',
#  'eigenvals',
#  'el_test',
#  'ess',
#  'f_pvalue',
#  'f_test',
#  'fittedvalues',
#  'fvalue',
#  'get_influence',
#  'get_prediction',
#  'get_robustcov_results',
#  'initialize',
#  'k_constant',
#  'llf',
#  'load',
#  'model',
#  'mse_model',
#  'mse_resid',
#  'mse_total',
#  'nobs',
#  'normalized_cov_params',
#  'outlier_test',
#  'params',
#  'predict',
#  'pvalues',
#  'remove_data',
#  'resid',
#  'resid_pearson',
#  'rsquared',
#  'rsquared_adj',
#  'save',
#  'scale',
#  'ssr',
#  'summary',
#  'summary2',
#  't_test',
#  't_test_pairwise',
#  'tvalues',
#  'uncentered_tss',
#  'use_t',
#  'wald_test',
#  'wald_test_terms',
#  'wresid']

# %% [markdown]
# ---
# # SARIMA Models
# Lets make an SARIMA model for the brazilian industrial production (not seasonaly adjusted). First step is to grab the industrial production series.

# %%
df = get_SGS_data(21859, 'ind prod')
df.index.freq='MS'
df.plot()

# %% [markdown]
# First thing to do is to look at the correlogram

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
fig = sm.graphics.tsa.plot_acf(df['ind prod'], lags=40, ax=axes[0])
fig = sm.graphics.tsa.plot_pacf(df['ind prod'], lags=40, ax=axes[1])

# %% [markdown]
# We can do an unit root test in order to see if we have to take the firt difference to model the series.

# %%
adf_test = sm.tsa.stattools.adfuller(df['ind prod'], regression='c', regresults=False)
adf_test[1]  # pvalue of the test
# Out:
# 0.14788475478837637

# %% [markdown]
# We do not reject the null hypothesis, so the series of industrial production has a unit root.
#
# Now let differentiate the series and look at the correlogram again.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15,5))
fig = sm.graphics.tsa.plot_acf(df['ind prod'].diff(1).diff(12).dropna(), lags=np.arange(1,40), ax=axes[0])
fig = sm.graphics.tsa.plot_pacf(df['ind prod'].diff(1).diff(12).dropna(), lags=np.arange(1,40), ax=axes[1])

# %% [markdown]
# We see that the ACF has significant values for in the lags that are a multiple of 12. Now we fit the model.

# %%
mod = sm.tsa.statespace.SARIMAX(df['ind prod'], order=(0,1,0), seasonal_order=(1,1,1,12))
res = mod.fit(disp=False)
res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                           ind prod   No. Observations:                  198
# Model:             SARIMAX(0, 1, 0)x(1, 1, 1, 12)   Log Likelihood                -476.977
# Date:                            Sun, 26 Aug 2018   AIC                            959.955
# Time:                                    21:06:05   BIC                            969.616
# Sample:                                01-01-2002   HQIC                           963.870
#                                      - 06-01-2018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.1967      0.116      1.698      0.090      -0.030       0.424
# ma.S.L12      -0.9995     27.762     -0.036      0.971     -55.412      53.413
# sigma2         8.6847    240.603      0.036      0.971    -462.889     480.258
# ===================================================================================
# Ljung-Box (Q):                      202.46   Jarque-Bera (JB):                 0.26
# Prob(Q):                              0.00   Prob(JB):                         0.88
# Heteroskedasticity (H):               1.23   Skew:                            -0.02
# Prob(H) (two-sided):                  0.42   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# Now let's make a forecast based on the estimated model

# %%
# generate predictions
last_date = df.index[-1]
predict = res.get_prediction(start=last_date+1, end=last_date+24)
predict_ci = predict.conf_int(alpha=0.1)

# generate chart
fig, ax = plt.subplots(figsize=(12,6))
ax.plot(df['ind prod'])
ax.plot(predict.predicted_mean, 'r--')
#ax.plot(predict.predicted_mean[-nforecast:], 'k--', linestyle='--', linewidth=2)
ax.fill_between(predict.predicted_mean.index, predict_ci['lower ind prod'], predict_ci['upper ind prod'], alpha=0.15)
plt.show()

# %% [markdown]
# ---
# # VAR Models

# %%
df = pd.DataFrame()
df = pd.concat([df, get_SGS_data(22110, 'consumo')], axis=1)
df = pd.concat([df, get_SGS_data(22113, 'investimento')], axis=1)
df = pd.concat([df, get_SGS_data(432, 'selic').resample('M').last()], axis=1)
df = df.resample('Q').mean().diff(1)

df.plot()

# %%
mod = sm.tsa.VARMAX(df, order=(2,0), trend='c')
res = mod.fit(maxiter=1000)  # VAR models tend take a while to converge, default is maxiter=50
res.summary()
# Out:
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# /anaconda3/lib/python3.6/site-packages/scipy/stats/_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     Statespace Model Results
# ================================================================================================
# Dep. Variable:     ['consumo', 'investimento', 'selic']   No. Observations:                   91
# Model:                                           VAR(2)   Log Likelihood                -543.678
#                                             + intercept   AIC                           1141.357
# Date:                                  Sun, 26 Aug 2018   BIC                           1209.150
# Time:                                          21:09:11   HQIC                          1168.707
# Sample:                                      03-31-1996
#                                            - 09-30-2018
# Covariance Type:                                    opg
# ====================================================================================
# Ljung-Box (Q):               nan, nan, nan   Jarque-Bera (JB):   13.30, 19.03, 69.54
# Prob(Q):                     nan, nan, nan   Prob(JB):              0.00, 0.00, 0.00
# Heteroskedasticity (H):   0.93, 1.29, 0.07   Skew:                -0.78, -0.79, 0.29
# Prob(H) (two-sided):      0.85, 0.50, 0.00   Kurtosis:              4.08, 4.64, 7.59
#                             Results for equation consumo
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const               0.4444      0.362      1.227      0.220      -0.265       1.154
# L1.consumo          0.3295      0.168      1.958      0.050      -0.000       0.659
# L1.investimento    -0.0091      0.071     -0.129      0.897      -0.147       0.129
# L1.selic           -0.0593      0.247     -0.240      0.810      -0.543       0.424
# L2.consumo          0.1312      0.201      0.652      0.514      -0.263       0.525
# L2.investimento    -0.0056      0.074     -0.075      0.941      -0.152       0.140
# L2.selic            0.0198      0.256      0.077      0.939      -0.483       0.522
#                          Results for equation investimento
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.6081      0.952     -0.639      0.523      -2.474       1.258
# L1.consumo          1.0225      0.357      2.865      0.004       0.323       1.722
# L1.investimento     0.2676      0.143      1.866      0.062      -0.013       0.549
# L1.selic           -0.0108      0.856     -0.013      0.990      -1.688       1.666
# L2.consumo          0.3329      0.467      0.713      0.476      -0.583       1.249
# L2.investimento    -0.2753      0.154     -1.793      0.073      -0.576       0.026
# L2.selic            0.0274      0.755      0.036      0.971      -1.452       1.506
#                              Results for equation selic
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              -0.3535      0.264     -1.338      0.181      -0.872       0.165
# L1.consumo          0.0757      0.247      0.307      0.759      -0.408       0.559
# L1.investimento    -0.0044      0.121     -0.036      0.971      -0.242       0.233
# L1.selic            1.4691      0.076     19.414      0.000       1.321       1.617
# L2.consumo          0.1215      0.262      0.463      0.643      -0.393       0.636
# L2.investimento    -0.0336      0.099     -0.339      0.734      -0.228       0.160
# L2.selic           -0.7318      0.091     -8.007      0.000      -0.911      -0.553
#                                      Error covariance matrix
# =================================================================================================
#                                     coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# sqrt.var.consumo                  1.6382      0.184      8.887      0.000       1.277       2.000
# sqrt.cov.consumo.investimento     2.0769      0.516      4.022      0.000       1.065       3.089
# sqrt.var.investimento             3.3660      0.329     10.228      0.000       2.721       4.011
# sqrt.cov.consumo.selic            0.1270      0.510      0.249      0.803      -0.873       1.127
# sqrt.cov.investimento.selic       0.2310      0.446      0.518      0.604      -0.642       1.104
# sqrt.var.selic                    1.4919      0.170      8.753      0.000       1.158       1.826
# =================================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Impulse-Response Functions

# %%
irf = res.impulse_responses(steps=12, impulse=0, orthogonalized=True, cumulative=False)
irf.plot()
plt.show()
